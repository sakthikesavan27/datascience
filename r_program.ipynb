# %%
library(ggplot2)

# %%
df <- read.csv("heart.csv")

# %%
mean_age <- mean(df$age, na.rm=TRUE)
median_age <- median(df$age, na.rm=TRUE)
var_age <- var(df$age, na.rm=TRUE)

print(paste("Mean Age:", mean_age))
print(paste("Median Age:", median_age))
print(paste("Variance Age:", var_age))
# Out:
# [1] "Mean Age: 54.3663366336634"
# [1] "Median Age: 55"
# [1] "Variance Age: 82.4845583896138"

# %%
ggplot(df, aes(x=factor(cp))) +
  geom_bar(fill="skyblue", color="black") +
  labs(title="Count of Chest Pain Types",
       x="Chest Pain Type",
       y="Count")
# Out:
# plot without title
